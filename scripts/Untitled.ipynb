# %%
raw_seq = [10, 1, 123, 79, 61, 47, 15.1, 1650, 14, 16, 110, 79, 21, 156, 44, 160, 91]

# %%
import pandas as pd
df = pd.DataFrame(raw_seq)
df
# Out:
#          0
# 0     10.0
# 1      1.0
# 2    123.0
# 3     79.0
# 4     61.0
# 5     47.0
# 6     15.1
# 7   1650.0
# 8     14.0
# 9     16.0
# 10   110.0
# 11    79.0
# 12    21.0
# 13   156.0
# 14    44.0
# 15   160.0
# 16    91.0

# %%
import pandas as pd
df = pd.DataFrame(raw_seq)
df
# Out:
#          0
# 0     10.0
# 1      1.0
# 2    123.0
# 3     79.0
# 4     61.0
# 5     47.0
# 6     15.1
# 7   1650.0
# 8     14.0
# 9     16.0
# 10   110.0
# 11    79.0
# 12    21.0
# 13   156.0
# 14    44.0
# 15   160.0
# 16    91.0

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
normalizeddata = scaler.fit_transform(df.values)
normalizeddata = pd.DataFrame(normalizeddata)
normalizeddata
# Out:
#            0
# 0   0.005458
# 1   0.000000
# 2   0.073984
# 3   0.047301
# 4   0.036386
# 5   0.027896
# 6   0.008551
# 7   1.000000
# 8   0.007884
# 9   0.009096
# 10  0.066101
# 11  0.047301
# 12  0.012129
# 13  0.093996
# 14  0.026076
# 15  0.096422
# 16  0.054579

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
normalizeddata = scaler.fit_transform(df.values)
normalizeddata = pd.DataFrame(normalizeddata)
normalizeddata
# Out:
#            0
# 0   0.005458
# 1   0.000000
# 2   0.073984
# 3   0.047301
# 4   0.036386
# 5   0.027896
# 6   0.008551
# 7   1.000000
# 8   0.007884
# 9   0.009096
# 10  0.066101
# 11  0.047301
# 12  0.012129
# 13  0.093996
# 14  0.026076
# 15  0.096422
# 16  0.054579

# %%
# Out:
# Requirement already satisfied: scikit-learn in /home/h1/607781/.local/lib/python3.8/site-packages (1.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/h1/607781/.local/lib/python3.8/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/h1/607781/.local/lib/python3.8/site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: scipy>=1.3.2 in /home/h1/607781/.local/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/h1/607781/.local/lib/python3.8/site-packages (from scikit-learn) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(normalizeddata)

# %%
n_steps = 2

# %%
def split_sequence(sequence, n_steps):
    x, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        x.append(seq_x)
        y.append(seq_y)
    return array(x), array(y)

# %%
from numpy import array
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

# %%
x, y = split_sequence(df[0], n_steps)

# %%
for i in range(len(x)):
    print(x[i],y[i])
# Out:
# [10.  1.] 123.0
# [  1. 123.] 79.0
# [123.  79.] 61.0
# [79. 61.] 47.0
# [61. 47.] 15.1
# [47.  15.1] 1650.0
# [  15.1 1650. ] 14.0
# [1650.   14.] 16.0
# [14. 16.] 110.0
# [ 16. 110.] 79.0
# [110.  79.] 21.0
# [79. 21.] 156.0
# [ 21. 156.] 44.0
# [156.  44.] 160.0
# [ 44. 160.] 91.0
