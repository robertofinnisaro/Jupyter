# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
import seaborn as sns
from numpy import mean
from numpy import std
from sklearn.preprocessing import LabelEncoder as le
# %matplotlib inline
plt.rcParams['agg.path.chunksize'] = 100000
# Out:
# 2023-05-11 09:45:39.849881: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-11 09:45:39.876141: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-11 09:45:39.877348: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-11 09:45:40.388337: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
np.random.seed(7)

# %%
location_datasetdir = '../datasets/location dataset/'
figuredir = '../figures/location/'
datasetdir = '../datasets/new location dataset/'

import os

CHECK_FOLDER = os.path.isdir(datasetdir)

if not CHECK_FOLDER:
    os.makedirs(datasetdir)
    print("Created folder : ", datasetdir)
else:
    print(datasetdir, "Folder already exists")
    
CHECK_FOLDER = os.path.isdir(figuredir)

if not CHECK_FOLDER:
    os.makedirs(figuredir)
    print("Created folder : ", figuredir)
else:
    print(figuredir, "Folder already exists")
# Out:
# ../datasets/new location dataset/ Folder already exists
# ../figures/location/ Folder already exists

# %%
dataset = "location-dataset.txt"
data = pd.read_csv(location_datasetdir + dataset)
data.info(), data.head(), data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3530 entries, 0 to 3529
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   location  3530 non-null   float64
# dtypes: float64(1)
# memory usage: 27.7 KB
# (None,
#     location
#  0  0.200000
#  1  0.222400
#  2  0.254621
#  3  0.266664
#  4  0.298531,
#  (3530, 1))

# %%
def configure_parameters(b, e, o, n, t):
    #Hyper parameters:
    batchSize = b
    epochs = e
    optimizer = o
    neurons = n

     return batchSize, epochs, optimizer, neurons
#General parameters:
trainingSize = 75

# %%
data['location'].plot(color='b', figsize=(15,3))
plt.legend(loc=2)
plt.xlabel("Time")
plt.ylabel("Location")
plt.tick_params(axis='both',labelsize=14)
plt.legend(loc='upper right')
plt.legend(title="Locations")
plt.savefig(figuredir + "location-over-time.png", bbox_inches='tight', dpi=1200)

# %%
location = data['location']
location = pd.DataFrame(location)
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3530 entries, 0 to 3529
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   location  3530 non-null   float64
# dtypes: float64(1)
# memory usage: 27.7 KB

# %%
location.head()
# Out:
#    location
# 0  0.200000
# 1  0.222400
# 2  0.254621
# 3  0.266664
# 4  0.298531

# %%
df = location
df
# Out:
#       location
# 0     0.200000
# 1     0.222400
# 2     0.254621
# 3     0.266664
# 4     0.298531
# ...        ...
# 3525  3.776047
# 3526  3.755918
# 3527  3.765791
# 3528  3.765665
# 3529  3.765539
#
# [3530 rows x 1 columns]

# %%
df.plot(color='b',figsize = (15,3))
# Out:
# <Axes: >

# %%
scaler = MinMaxScaler(feature_range=(0,1))
normalisedLocation = scaler.fit_transform(df)
normalisedLocation = pd.DataFrame(normalisedLocation)

# %%
normalisedLocation.plot(color='b',figsize = (15, 3))
# Out:
# <Axes: >

# %%
dataset = normalisedLocation
dataset = pd.DataFrame(dataset)
dataset
# Out:
#              0
# 0     0.000000
# 1     0.003065
# 2     0.007473
# 3     0.009120
# 4     0.013480
# ...        ...
# 3525  0.489242
# 3526  0.486489
# 3527  0.487839
# 3528  0.487822
# 3529  0.487805
#
# [3530 rows x 1 columns]

# %%
train_size = int(len(dataset) * (trainingSize/100))
test_size = len(dataset) - train_size
train, test = dataset[0:train_size], dataset[train_size:len(dataset)]

print("Total Dataset        = ", len(dataset))
print("Training Sample      = ", train_size)
print("Testing Sample       = ", test_size)
# Out:
# Total Dataset        =  3530
# Training Sample      =  2647
# Testing Sample       =  883

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset.iloc[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset.iloc[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 25
trainX, trainY = create_dataset(train[0], look_back)
testX, testY = create_dataset(test[0], look_back)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
[batchSize, epochs, optimizer, neurons] = configure_parameters(1, 50, 'adam', 250)
model = Sequential()
# model.add(LSTM(500, input_shape=(1, look_back)))
model.add(LSTM(5, input_shape=(1, look_back)))
# model.add(Dense(150))
# model.add(Dense(100))
model.add(Dense(neurons))
model.add(Dense(1))
model.compile(loss='mean_absolute_error', optimizer='adam')
model.fit(trainX, trainY, epochs=epochs, batch_size=batchSize, verbose=1)
# Out:
# Epoch 1/250
# 2023-05-11 09:45:43.853917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-11 09:45:43.855422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-11 09:45:43.856128: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-11 09:45:44.055687: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-11 09:45:44.057009: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-11 09:45:44.059218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-11 09:45:44.441665: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-11 09:45:44.443383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-11 09:45:44.444302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 27/27 [==============================] - 1s 2ms/step - loss: 0.3812
# Epoch 2/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.1474
# Epoch 3/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0551
# Epoch 4/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 5/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 6/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 7/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 8/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 9/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 10/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 11/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 12/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0066
# Epoch 13/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 14/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0056
# Epoch 15/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0048
# Epoch 16/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0046
# Epoch 17/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0050
# Epoch 18/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 19/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 20/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 21/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0090
# Epoch 22/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 23/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 24/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 25/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0043
# Epoch 26/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 27/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 28/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 29/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 180/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 181/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 182/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0056
# Epoch 183/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 184/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 185/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 186/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0036
# Epoch 187/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 188/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0036
# Epoch 189/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 190/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 191/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 192/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 193/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 194/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 195/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 196/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 197/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 198/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 199/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 200/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 201/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 202/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 203/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 204/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 205/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 206/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 207/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 208/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 209/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0042
# Epoch 210/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 211/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0031
# Epoch 212/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 213/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 214/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 215/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 216/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 217/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0034
# Epoch 218/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 219/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 220/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 221/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0024
# Epoch 222/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 223/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 224/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 225/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 226/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 227/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 228/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 229/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 230/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 231/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 232/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0058
# Epoch 233/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 234/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0025
# Epoch 235/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 236/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 237/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 238/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 239/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 240/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0017
# Epoch 241/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 242/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0016
# Epoch 243/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 244/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 245/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 246/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 247/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 248/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0018
# Epoch 249/250
# 27/27 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 250/250
# 27/27 [==============================] - 0s 2ms/step - loss: 0.0024

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

print('Train Score: MAE',mean_absolute_error(trainY[0], trainPredict[:,0]))
print('Test Score: MAE',mean_absolute_error(testY[0], testPredict[:,0]))

MAEPTr = mean_absolute_percentage_error(trainY[0], trainPredict[:,0])
MAEPTs = mean_absolute_percentage_error(testY[0], testPredict[:,0])

print('Train Score: MARP = {}%'.format(MAEPTr))
print('Test Score: MARP = {}%'.format(MAEPTs))
# Out:
# 82/82 [==============================] - 0s 955us/step
# 2023-05-11 09:45:55.920389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-11 09:45:55.922429: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-11 09:45:55.923263: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 27/27 [==============================] - 0s 894us/step
# Train Score: MAE 0.017719646527851265
# Test Score: MAE 0.016366005836107856
# Train Score: MARP = 0.003961081188302864%
# Test Score: MARP = 0.0030564324236739115%

# %%
dataset.shape
# Out:
# (3530, 1)

# %%
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

plt.figure(figsize=(10,5))
plt.plot(scaler.inverse_transform(dataset), label='dataset',color='blue')
plt.plot(testPredictPlot,label='Prediction',color='orange')

plt.legend(loc=2)
plt.ylabel=("Time")
plt.xlabel=("Location")

plt.savefig(figuredir + "LSTM-Forcasting-after-filter-moving-average-"+str(trainingSize)+".png",bbox_inches='tight', dpi=1200)
plt.show()
