# %%
import random

# %%
x = list()

# %%
for i in range(0, 100):
    ran = random.randint(0, 100)
    x.append(ran)

# %%
print(x)
# Out:
# [42, 87, 27, 8, 40, 12, 82, 38, 41, 56, 78, 61, 34, 22, 8, 38, 81, 28, 71, 21, 74, 22, 97, 15, 5, 57, 74, 22, 50, 11, 67, 15, 51, 75, 64, 93, 96, 59, 52, 1, 87, 86, 25, 38, 8, 47, 60, 67, 5, 84, 23, 46, 67, 93, 47, 31, 100, 97, 50, 86, 3, 56, 86, 28, 7, 10, 29, 35, 20, 38, 99, 87, 31, 77, 67, 40, 86, 4, 78, 24, 1, 99, 12, 91, 47, 23, 77, 9, 64, 73, 93, 68, 25, 81, 43, 37, 94, 65, 14, 5]

# %%
import pandas as pd
df = pd.DataFrame(x)
# df = pd.DataFrame(x, columns = ['location'])
df.rename(columns = {0:'TEST'}, inplace = True)
df
# Out:
#     TEST
# 0     42
# 1     87
# 2     27
# 3      8
# 4     40
# ..   ...
# 95    37
# 96    94
# 97    65
# 98    14
# 99     5
#
# [100 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df)
